# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from sklearn.utils import class_weight
from sklearn.preprocessing import OneHotEncoder

# Read the dataframe
df = pd.read_csv("dataframe.csv")

# Drop any rows with missing values
df = df.dropna()

# Split the data into input features (X) and target variable (y)
X = df.drop("y", axis=1).values
y = df["y"].values

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from imblearn.over_sampling import SMOTE

# Apply SMOTE to balance the dataset
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y)

#oversampler = RandomOverSampler(random_state=42)
#X_res, y_res = oversampler.fit_resample(X,y)

# %%
# Determine the number of unique critical error types
num_classes = len(np.unique(y))
print(num_classes)

# Encode the target variable using LabelEncoder and one-hot encoding
label_encoder = LabelEncoder()
y_res = label_encoder.fit_transform(y_res)
y_res = to_categorical(y_res)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)
# Out:
# 12

# %%
# Assuming X_train and X_test are your input data arrays
#X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Assuming y_train and y_test are your label arrays
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, BatchNormalization, Activation, MaxPooling1D, Add, GlobalAveragePooling1D, Dense

def residual_block(input_tensor, filters, kernel_size, strides=1):
    x = Conv1D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv1D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    
    # Downsample the input tensor if strides=2
    if strides == 2:
        input_tensor = Conv1D(filters, 1, strides=strides, padding='same')(input_tensor)
    
    x = Add()([x, input_tensor])
    x = Activation('relu')(x)
    return x

# Input layer
inputs = Input(shape=(78, 1))

# Initial convolution
x = Conv1D(64, 7, padding='same')(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# Residual blocks
x = residual_block(x, 64, 3)
x = residual_block(x, 64, 3)
x = residual_block(x, 64, 3)

x = residual_block(x, 128, 3, strides=2)
x = residual_block(x, 128, 3)
x = residual_block(x, 128, 3)

x = residual_block(x, 256, 3, strides=2)
x = residual_block(x, 256, 3)
x = residual_block(x, 256, 3)

# Global average pooling
x = GlobalAveragePooling1D()(x)

# Output layer
outputs = Dense(12, activation='softmax')(x)

# Create the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 78, 1)]      0           []
#
#  conv1d_41 (Conv1D)             (None, 78, 64)       512         ['input_6[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 78, 64)      256         ['conv1d_41[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 78, 64)       0           ['batch_normalization_39[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 78, 64)       12352       ['activation_37[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 78, 64)      256         ['conv1d_42[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 78, 64)       0           ['batch_normalization_40[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 78, 64)       12352       ['activation_38[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 78, 64)      256         ['conv1d_43[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 78, 64)       0           ['batch_normalization_41[0][0]',
#                                                                   'activation_37[0][0]']
#
#  activation_39 (Activation)     (None, 78, 64)       0           ['add_17[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 78, 64)       12352       ['activation_39[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 78, 64)      256         ['conv1d_44[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 78, 64)       0           ['batch_normalization_42[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 78, 64)       12352       ['activation_40[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 78, 64)      256         ['conv1d_45[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 78, 64)       0           ['batch_normalization_43[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_41 (Activation)     (None, 78, 64)       0           ['add_18[0][0]']
#
#  conv1d_46 (Conv1D)             (None, 78, 64)       12352       ['activation_41[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 78, 64)      256         ['conv1d_46[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 78, 64)       0           ['batch_normalization_44[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 78, 64)       12352       ['activation_42[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 78, 64)      256         ['conv1d_47[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 78, 64)       0           ['batch_normalization_45[0][0]',
#                                                                   'activation_41[0][0]']
#
#  activation_43 (Activation)     (None, 78, 64)       0           ['add_19[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 39, 128)      24704       ['activation_43[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 39, 128)     512         ['conv1d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 39, 128)      0           ['batch_normalization_46[0][0]']
#
#  conv1d_49 (Conv1D)             (None, 39, 128)      49280       ['activation_44[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 39, 128)     512         ['conv1d_49[0][0]']
#  ormalization)
#
#  conv1d_50 (Conv1D)             (None, 39, 128)      8320        ['activation_43[0][0]']
#
#  add_20 (Add)                   (None, 39, 128)      0           ['batch_normalization_47[0][0]',
#                                                                   'conv1d_50[0][0]']
#
#  activation_45 (Activation)     (None, 39, 128)      0           ['add_20[0][0]']
#
#  conv1d_51 (Conv1D)             (None, 39, 128)      49280       ['activation_45[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 39, 128)     512         ['conv1d_51[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 39, 128)      0           ['batch_normalization_48[0][0]']
#
#  conv1d_52 (Conv1D)             (None, 39, 128)      49280       ['activation_46[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 39, 128)     512         ['conv1d_52[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 39, 128)      0           ['batch_normalization_49[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_47 (Activation)     (None, 39, 128)      0           ['add_21[0][0]']
#
#  conv1d_53 (Conv1D)             (None, 39, 128)      49280       ['activation_47[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 39, 128)     512         ['conv1d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 39, 128)      0           ['batch_normalization_50[0][0]']
#
#  conv1d_54 (Conv1D)             (None, 39, 128)      49280       ['activation_48[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 39, 128)     512         ['conv1d_54[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 39, 128)      0           ['batch_normalization_51[0][0]',
#                                                                   'activation_47[0][0]']
#
#  activation_49 (Activation)     (None, 39, 128)      0           ['add_22[0][0]']
#
#  conv1d_55 (Conv1D)             (None, 20, 256)      98560       ['activation_49[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 20, 256)     1024        ['conv1d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 20, 256)      0           ['batch_normalization_52[0][0]']
#
#  conv1d_56 (Conv1D)             (None, 20, 256)      196864      ['activation_50[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 20, 256)     1024        ['conv1d_56[0][0]']
#  ormalization)
#
#  conv1d_57 (Conv1D)             (None, 20, 256)      33024       ['activation_49[0][0]']
#
#  add_23 (Add)                   (None, 20, 256)      0           ['batch_normalization_53[0][0]',
#                                                                   'conv1d_57[0][0]']
#
#  activation_51 (Activation)     (None, 20, 256)      0           ['add_23[0][0]']
#
#  conv1d_58 (Conv1D)             (None, 20, 256)      196864      ['activation_51[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 20, 256)     1024        ['conv1d_58[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 20, 256)      0           ['batch_normalization_54[0][0]']
#
#  conv1d_59 (Conv1D)             (None, 20, 256)      196864      ['activation_52[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 20, 256)     1024        ['conv1d_59[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 20, 256)      0           ['batch_normalization_55[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_53 (Activation)     (None, 20, 256)      0           ['add_24[0][0]']
#
#  conv1d_60 (Conv1D)             (None, 20, 256)      196864      ['activation_53[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 20, 256)     1024        ['conv1d_60[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 20, 256)      0           ['batch_normalization_56[0][0]']
#
#  conv1d_61 (Conv1D)             (None, 20, 256)      196864      ['activation_54[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 20, 256)     1024        ['conv1d_61[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 20, 256)      0           ['batch_normalization_57[0][0]',
#                                                                   'activation_53[0][0]']
#
#  activation_55 (Activation)     (None, 20, 256)      0           ['add_25[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 256)         0           ['activation_55[0][0]']
#  obalAveragePooling1D)
#
#  dense_1 (Dense)                (None, 12)           3084        ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 1,484,044
# Trainable params: 1,478,540
# Non-trainable params: 5,504
# __________________________________________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 397/397 [==============================] - 43s 93ms/step - loss: 1.3691 - accuracy: 0.5455 - val_loss: 3.6953 - val_accuracy: 0.5153
# Epoch 2/50
# 397/397 [==============================] - 45s 113ms/step - loss: 0.8509 - accuracy: 0.7258 - val_loss: 1.3319 - val_accuracy: 0.5790
# Epoch 3/50
# 397/397 [==============================] - 46s 116ms/step - loss: 0.7254 - accuracy: 0.7638 - val_loss: 2.7879 - val_accuracy: 0.4529
# Epoch 4/50
# 397/397 [==============================] - 43s 108ms/step - loss: 0.6635 - accuracy: 0.7792 - val_loss: 0.8800 - val_accuracy: 0.7231
# Epoch 5/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.6015 - accuracy: 0.7983 - val_loss: 0.9557 - val_accuracy: 0.7348
# Epoch 6/50
# 397/397 [==============================] - 45s 113ms/step - loss: 0.5683 - accuracy: 0.8088 - val_loss: 0.5778 - val_accuracy: 0.8136
# Epoch 7/50
# 397/397 [==============================] - 45s 112ms/step - loss: 0.5495 - accuracy: 0.8125 - val_loss: 0.5285 - val_accuracy: 0.8243
# Epoch 8/50
# 397/397 [==============================] - 45s 113ms/step - loss: 0.5189 - accuracy: 0.8284 - val_loss: 1.0577 - val_accuracy: 0.6853
# Epoch 9/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.4972 - accuracy: 0.8309 - val_loss: 3.2152 - val_accuracy: 0.5872
# Epoch 10/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.4813 - accuracy: 0.8353 - val_loss: 0.5210 - val_accuracy: 0.8225
# Epoch 11/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.4548 - accuracy: 0.8436 - val_loss: 0.7356 - val_accuracy: 0.7547
# Epoch 12/50
# 397/397 [==============================] - 45s 113ms/step - loss: 0.4470 - accuracy: 0.8489 - val_loss: 0.7145 - val_accuracy: 0.7764
# Epoch 13/50
# 397/397 [==============================] - 46s 116ms/step - loss: 0.4315 - accuracy: 0.8525 - val_loss: 0.9186 - val_accuracy: 0.7420
# Epoch 14/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.4246 - accuracy: 0.8538 - val_loss: 0.5386 - val_accuracy: 0.8184
# Epoch 15/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.4047 - accuracy: 0.8636 - val_loss: 0.6081 - val_accuracy: 0.8073
# Epoch 16/50
# 397/397 [==============================] - 45s 115ms/step - loss: 0.3910 - accuracy: 0.8662 - val_loss: 0.5840 - val_accuracy: 0.8073
# Epoch 17/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.3963 - accuracy: 0.8628 - val_loss: 0.7261 - val_accuracy: 0.7657
# Epoch 18/50
# 397/397 [==============================] - 45s 114ms/step - loss: 0.3887 - accuracy: 0.8679 - val_loss: 1.0830 - val_accuracy: 0.7010
# Epoch 19/50
# 397/397 [==============================] - 46s 115ms/step - loss: 0.3595 - accuracy: 0.8738 - val_loss: 0.4202 - val_accuracy: 0.8581
# Epoch 20/50
# 397/397 [==============================] - 46s 116ms/step - loss: 0.3524 - accuracy: 0.8741 - val_loss: 0.5909 - val_accuracy: 0.7979
# Epoch 21/50
# 397/397 [==============================] - 46s 115ms/step - loss: 0.3403 - accuracy: 0.8812 - val_loss: 0.5366 - val_accuracy: 0.8373
# Epoch 22/50
# 397/397 [==============================] - 47s 119ms/step - loss: 0.3504 - accuracy: 0.8793 - val_loss: 0.5620 - val_accuracy: 0.7997
# Epoch 23/50
# 397/397 [==============================] - 48s 122ms/step - loss: 0.3363 - accuracy: 0.8841 - val_loss: 0.4961 - val_accuracy: 0.8417
# Epoch 24/50
# 397/397 [==============================] - 48s 122ms/step - loss: 0.3256 - accuracy: 0.8851 - val_loss: 0.4940 - val_accuracy: 0.8499
# Epoch 25/50
# 397/397 [==============================] - 46s 117ms/step - loss: 0.3252 - accuracy: 0.8873 - val_loss: 2.0540 - val_accuracy: 0.6030
# Epoch 26/50
#  85/397 [=====>........................] - ETA: 34s - loss: 0.2839 - accuracy: 0.8967
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Train the model
# ----> 2 model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~\.conda\envs\DeepLearning\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
import numpy as np
y_pred = model.predict(X_test)

y_pred_classes = []
y_real_classes = []

for item in y_pred:
    y_pred_classes.append(np.argmax(item))

for item in y_test:
    y_real_classes.append(np.argmax(item))
    
print(y_pred_classes[0])
print(y_real_classes[0])
# Assuming your classes are labeled from 0 to 25
predicted_class = np.argmax(y_pred[0])
probability = y_pred[0][predicted_class]

print("Predicted class:", predicted_class)
print("Probability:", probability)

# %%
import numpy as np
from sklearn.metrics import classification_report

print(classification_report(y_real_classes, y_pred_classes))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_real_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
