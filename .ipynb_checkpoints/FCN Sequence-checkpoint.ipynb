# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from sklearn.utils import class_weight
from sklearn.preprocessing import OneHotEncoder
import csv

# Read data for X and y
X = pd.read_csv("X.csv").values
y = pd.read_csv("y.csv").values

# Flatten list y
y = [item for sublist in y for item in sublist]

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from imblearn.over_sampling import SMOTE

# Apply SMOTE to balance the dataset
#sm = SMOTE(random_state=42)
#X_res, y_res = sm.fit_resample(X, y)

oversampler = RandomOverSampler(random_state=42)
X_res, y_res = oversampler.fit_resample(X,y)

# %%
# Determine the number of unique critical error types
num_classes = len(np.unique(y_res))
class_names = np.unique(y_res)

# Encode the target variable using LabelEncoder and one-hot encoding
label_encoder = LabelEncoder()
y_res = label_encoder.fit_transform(y_res)
y_res = to_categorical(y_res)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
# Define the input shape
input_shape = (300,)

# Create the FCN model
model = keras.models.Sequential()
model.add(keras.layers.Dense(128, activation='relu',input_shape=input_shape))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(12, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               38528
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 12)                780
#
# =================================================================
# Total params: 47,564
# Trainable params: 47,564
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 394/394 [==============================] - 2s 3ms/step - loss: 2.3790 - accuracy: 0.3046 - val_loss: 1.8686 - val_accuracy: 0.3804
# Epoch 2/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.7961 - accuracy: 0.3966 - val_loss: 1.7734 - val_accuracy: 0.4169
# Epoch 3/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.6592 - accuracy: 0.4380 - val_loss: 1.6427 - val_accuracy: 0.4575
# Epoch 4/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.5702 - accuracy: 0.4668 - val_loss: 1.5448 - val_accuracy: 0.4879
# Epoch 5/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.4987 - accuracy: 0.4940 - val_loss: 1.5345 - val_accuracy: 0.4848
# Epoch 6/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.4298 - accuracy: 0.5215 - val_loss: 1.4954 - val_accuracy: 0.5219
# Epoch 7/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.3869 - accuracy: 0.5409 - val_loss: 1.4386 - val_accuracy: 0.5359
# Epoch 8/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.3201 - accuracy: 0.5655 - val_loss: 1.4212 - val_accuracy: 0.5523
# Epoch 9/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.2762 - accuracy: 0.5767 - val_loss: 1.3780 - val_accuracy: 0.5523
# Epoch 10/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.2285 - accuracy: 0.5920 - val_loss: 1.3582 - val_accuracy: 0.5520
# Epoch 11/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.2170 - accuracy: 0.5989 - val_loss: 1.3263 - val_accuracy: 0.5746
# Epoch 12/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.1718 - accuracy: 0.6110 - val_loss: 1.3189 - val_accuracy: 0.5879
# Epoch 13/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.1457 - accuracy: 0.6162 - val_loss: 1.3196 - val_accuracy: 0.5730
# Epoch 14/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.1021 - accuracy: 0.6351 - val_loss: 1.2727 - val_accuracy: 0.5888
# Epoch 15/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.0777 - accuracy: 0.6387 - val_loss: 1.2857 - val_accuracy: 0.6104
# Epoch 16/50
# 394/394 [==============================] - 1s 3ms/step - loss: 1.0632 - accuracy: 0.6438 - val_loss: 1.2688 - val_accuracy: 0.5961
# Epoch 17/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.0326 - accuracy: 0.6546 - val_loss: 1.2607 - val_accuracy: 0.6199
# Epoch 18/50
# 394/394 [==============================] - 1s 2ms/step - loss: 1.0105 - accuracy: 0.6613 - val_loss: 1.2349 - val_accuracy: 0.6196
# Epoch 19/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.9858 - accuracy: 0.6691 - val_loss: 1.2557 - val_accuracy: 0.6164
# Epoch 20/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.9812 - accuracy: 0.6714 - val_loss: 1.2676 - val_accuracy: 0.6202
# Epoch 21/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.9650 - accuracy: 0.6783 - val_loss: 1.2762 - val_accuracy: 0.6212
# Epoch 22/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.9585 - accuracy: 0.6815 - val_loss: 1.2477 - val_accuracy: 0.6247
# Epoch 23/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.9162 - accuracy: 0.6894 - val_loss: 1.2178 - val_accuracy: 0.6399
# Epoch 24/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.9083 - accuracy: 0.6952 - val_loss: 1.3237 - val_accuracy: 0.6190
# Epoch 25/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.8864 - accuracy: 0.6987 - val_loss: 1.2513 - val_accuracy: 0.6323
# Epoch 26/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.8849 - accuracy: 0.6997 - val_loss: 1.2577 - val_accuracy: 0.6434
# Epoch 27/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.8602 - accuracy: 0.7077 - val_loss: 1.2728 - val_accuracy: 0.6409
# Epoch 28/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.8433 - accuracy: 0.7128 - val_loss: 1.2436 - val_accuracy: 0.6494
# Epoch 29/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.8425 - accuracy: 0.7155 - val_loss: 1.3114 - val_accuracy: 0.6291
# Epoch 30/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.8194 - accuracy: 0.7226 - val_loss: 1.2672 - val_accuracy: 0.6418
# Epoch 31/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.8318 - accuracy: 0.7219 - val_loss: 1.2525 - val_accuracy: 0.6260
# Epoch 32/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.8091 - accuracy: 0.7250 - val_loss: 1.2896 - val_accuracy: 0.6431
# Epoch 33/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.7973 - accuracy: 0.7304 - val_loss: 1.3782 - val_accuracy: 0.6450
# Epoch 34/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7915 - accuracy: 0.7319 - val_loss: 1.3847 - val_accuracy: 0.6491
# Epoch 35/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7955 - accuracy: 0.7329 - val_loss: 1.2650 - val_accuracy: 0.6526
# Epoch 36/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7930 - accuracy: 0.7356 - val_loss: 1.5331 - val_accuracy: 0.6206
# Epoch 37/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.7641 - accuracy: 0.7414 - val_loss: 1.2843 - val_accuracy: 0.6450
# Epoch 38/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7804 - accuracy: 0.7406 - val_loss: 1.3545 - val_accuracy: 0.6491
# Epoch 39/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7406 - accuracy: 0.7479 - val_loss: 1.3965 - val_accuracy: 0.6589
# Epoch 40/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.7375 - accuracy: 0.7496 - val_loss: 1.3109 - val_accuracy: 0.6688
# Epoch 41/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7494 - accuracy: 0.7495 - val_loss: 1.3551 - val_accuracy: 0.6624
# Epoch 42/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7288 - accuracy: 0.7475 - val_loss: 1.2846 - val_accuracy: 0.6659
# Epoch 43/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.7285 - accuracy: 0.7477 - val_loss: 1.3519 - val_accuracy: 0.6653
# Epoch 44/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7137 - accuracy: 0.7575 - val_loss: 1.3909 - val_accuracy: 0.6564
# Epoch 45/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.7144 - accuracy: 0.7564 - val_loss: 1.3350 - val_accuracy: 0.6618
# Epoch 46/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.7210 - accuracy: 0.7547 - val_loss: 1.3861 - val_accuracy: 0.6688
# Epoch 47/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.7131 - accuracy: 0.7602 - val_loss: 1.4286 - val_accuracy: 0.6701
# Epoch 48/50
# 394/394 [==============================] - 1s 3ms/step - loss: 0.6961 - accuracy: 0.7597 - val_loss: 1.3702 - val_accuracy: 0.6710
# Epoch 49/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.6902 - accuracy: 0.7625 - val_loss: 1.3775 - val_accuracy: 0.6653
# Epoch 50/50
# 394/394 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.7677 - val_loss: 1.3769 - val_accuracy: 0.6637

# %%
y_pred = model.predict(X_test)
# Out:
# 99/99 [==============================] - 0s 980us/step

# %%
y_pred_classes = []
y_real_classes = []

for item in y_pred:
    y_pred_classes.append(np.argmax(item))

for item in y_test:
    y_real_classes.append(np.argmax(item))

# %%
import numpy as np
from sklearn.metrics import classification_report

print(classification_report(y_real_classes, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.33      0.39       287
#            1       0.61      0.79      0.69       268
#            2       0.86      0.88      0.87       266
#            3       0.80      0.78      0.79       270
#            4       0.38      0.39      0.38       264
#            5       0.93      1.00      0.96       276
#            6       0.81      0.95      0.88       244
#            7       0.61      0.53      0.56       252
#            8       0.57      0.45      0.50       246
#            9       0.66      0.92      0.77       266
#           10       0.71      0.57      0.63       245
#           11       0.44      0.36      0.40       268
#
#     accuracy                           0.66      3152
#    macro avg       0.65      0.66      0.65      3152
# weighted avg       0.65      0.66      0.65      3152

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_real_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
