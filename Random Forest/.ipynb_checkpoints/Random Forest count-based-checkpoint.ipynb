# %%
#Count-based approach
import pandas as pd

df = pd.read_csv("data/dataframe.csv")
df.head()

X = df.drop("y", axis=1).values
y = df["y"].values

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from imblearn.over_sampling import SMOTE

# Apply SMOTE to balance the dataset
#sm = SMOTE(random_state=42)
#X_res, y_res = sm.fit_resample(X, y)

oversampler = RandomOverSampler(random_state=42)
X_res, y_res = oversampler.fit_resample(X,y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, random_state = 42, test_size = 0.33)

# %%
#from sklearn.ensemble import RandomForestClassifier

#model = RandomForestClassifier(criterion = "entropy", n_estimators = 30)
#model.fit(X_train, y_train)

#print(model.score(X_test, y_test))
# Out:
# 0.9304281345565749

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score
import joblib

# Define the scoring metric
scorer = make_scorer(f1_score)

model = RandomForestClassifier()

grid_space={'max_depth':[3,5,10,None],
              'n_estimators':[10,20,30,40,50],
              'max_features':[1,3,5,7],
              'min_samples_leaf':[1,2,3],
              'min_samples_split':[1,2,3],
              'criterion': ["entropy","gini","log_loss"]
           }

grid = GridSearchCV(model,param_grid=grid_space,cv=3,scoring="f1_micro",verbose=10, n_jobs=-1)

# Enable verbose logging using joblib
joblib.parallel_backend('threading')

model_grid = grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 2160 candidates, totalling 6480 fits
# [CV 1/3; 1/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=10
# [CV 2/3; 1/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=10
# [CV 3/3; 1/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=10
# [CV 1/3; 2/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=20
# [CV 2/3; 2/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=20
# [CV 3/3; 2/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=20
# [CV 1/3; 3/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=30
# [CV 2/3; 3/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=30
# [CV 2/3; 1/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/3; 3/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=30
# [CV 1/3; 1/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/3; 2/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 1/3; 4/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=40
# [CV 3/3; 1/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/3; 4/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=40
# [CV 3/3; 4/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=40
# [CV 1/3; 2/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 1/3; 5/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=50
# [CV 1/3; 3/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 2/3; 5/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=50
# [CV 2/3; 3/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 3/3; 5/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=50
# [CV 3/3; 2/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 1/3; 6/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 1/3; 4/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 2/3; 6/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 2/3; 4/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 3/3; 6/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 2/3; 5/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/3; 7/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20
# [CV 3/3; 3/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 2/3; 7/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20
# [CV 3/3; 4/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 3/3; 7/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20
# [CV 1/3; 5/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/3; 8/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30
# [CV 3/3; 5/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/3; 8/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30
# [CV 2/3; 6/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.419 total time=   0.1s
# [CV 3/3; 8/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30
# [CV 1/3; 6/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.371 total time=   0.1s
# [CV 1/3; 9/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=40
# [CV 3/3; 6/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.435 total time=   0.1s
# [CV 2/3; 9/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=40
# [CV 2/3; 7/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.558 total time=   0.3s
# [CV 3/3; 9/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=40
# [CV 1/3; 7/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.499 total time=   0.3s
# [CV 1/3; 10/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/3; 7/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.406 total time=   0.3s
# [CV 2/3; 10/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/3; 8/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.549 total time=   0.4s
# [CV 3/3; 10/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/3; 8/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.528 total time=   0.5s
# [CV 1/3; 11/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=10
# [CV 3/3; 8/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.626 total time=   0.4s
# [CV 2/3; 11/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=10
# [CV 1/3; 11/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=10;, score=0.390 total time=   0.1s
# [CV 3/3; 11/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=10
# [CV 2/3; 9/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.641 total time=   0.5s
# [CV 1/3; 12/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=20
# [CV 1/3; 9/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.624 total time=   0.6s
# [CV 2/3; 12/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=20
# [CV 2/3; 11/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=10;, score=0.376 total time=   0.1s
# [CV 3/3; 12/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=20
# [CV 3/3; 11/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=3, n_estimators=10;, score
2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=30;, score=0.516 total time=   0.5s
# [CV 1/3; 41/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=10
# [CV 1/3; 41/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=10;, score=0.395 total time=   0.1s
# [CV 2/3; 41/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=10
# [CV 3/3; 38/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=30;, score=0.593 total time=   0.6s
# [CV 3/3; 41/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=10
# [CV 1/3; 39/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.588 total time=   0.7s
# [CV 1/3; 42/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=20
# [CV 2/3; 41/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=10;, score=0.429 total time=   0.1s
# [CV 2/3; 42/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=20
# [CV 3/3; 41/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=10;, score=0.338 total time=   0.1s
# [CV 3/3; 42/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=20
# [CV 2/3; 39/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.607 total time=   0.7s
# [CV 1/3; 43/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=30
# [CV 3/3; 39/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.616 total time=   0.7s
# [CV 2/3; 43/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=30
# [CV 1/3; 40/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50;, score=0.586 total time=   1.0s
# [CV 3/3; 43/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=30
# [CV 2/3; 40/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50;, score=0.627 total time=   1.0s
# [CV 1/3; 44/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=40
# [CV 1/3; 42/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=20;, score=0.479 total time=   0.6s
# [CV 2/3; 44/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=40
# [CV 2/3; 42/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=20;, score=0.515 total time=   0.6s
# [CV 3/3; 44/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=40
# [CV 3/3; 42/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=20;, score=0.486 total time=   0.7s
# [CV 1/3; 45/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=50
# [CV 3/3; 40/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50;, score=0.609 total time=   1.3s
# [CV 2/3; 45/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=50
# [CV 1/3; 43/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=30;, score=0.573 total time=   1.0s
# [CV 3/3; 45/2160] START criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=50
# [CV 2/3; 43/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=30;, score=0.559 total time=   1.0s
# [CV 1/3; 46/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=10
# [CV 1/3; 46/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/3; 46/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=10
# [CV 2/3; 46/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/3; 46/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=10
# [CV 3/3; 46/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/3; 47/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=20
# [CV 1/3; 47/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 2/3; 47/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=20
# [CV 2/3; 47/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 3/3; 47/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=20
# [CV 3/3; 47/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 1/3; 48/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=30
# [CV 1/3; 48/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 2/3; 48/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=30
# [CV 2/3; 48/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 3/3; 48/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=30
# [CV 3/3; 48/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 1/3; 49/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=40
# [CV 1/3; 49/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 2/3; 49/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=40
# [CV 2/3; 49/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 3/3; 49/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=40
# [CV 3/3; 49/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 1/3; 50/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=50
# [CV 1/3; 50/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/3; 50/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=50
# [CV 2/3; 50/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/3; 50/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=50
# [CV 3/3; 50/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/3; 51/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 3/3; 43/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=30;, score=0.516 total time=   1.1s
# [CV 2/3; 51/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 1/3; 51/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.460 total time=   0.3s
# [CV 3/3; 51/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=10
# [CV 1/3; 44/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.622 total time=   1.4s
# [CV 1/3; 52/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20
# [CV 2/3; 51/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.583 total time=   0.4s
# [CV 2/3; 52/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20
# [CV 2/3; 44/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.610 total time=   1.4s
# [CV 3/3; 52/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20
# [CV 3/3; 44/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.619 total time=   1.4s
# [CV 1/3; 53/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=30
# [CV 3/3; 51/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.454 total time=   0.4s
# [CV 2/3; 53/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=30
# [CV 1/3; 45/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=50;, score=0.635 total time=   1.7s
# [CV 3/3; 53/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=30
# [CV 2/3; 45/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=50;, score=0.566 total time=   1.7s
# [CV 1/3; 54/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40
# [CV 1/3; 52/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.610 total time=   0.8s
# [CV 2/3; 54/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40
# [CV 2/3; 52/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.595 total time=   0.7s
# [CV 3/3; 54/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40
# [CV 3/3; 45/2160] END criterion=entropy, max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=3, n_estimators=50;, score=0.591 total time=   1.8s
# [CV 1/3; 55/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 3/3; 52/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.623 total time=   0.8s
# [CV 2/3; 55/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 1/3; 53/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.619 total time=   1.2s
# [CV 3/3; 55/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50
# [CV 2/3; 53/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.629 total time=   1.2s
# [CV 1/3; 56/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=10
# [CV 3/3; 53/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.614 total time=   1.2s
# [CV 2/3; 56/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=10
# [CV 1/3; 56/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=10;, score=0.495 total time=   0.3s
# [CV 3/3; 56/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=10
# [CV 1/3; 54/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.643 total time=   1.5s
# [CV 1/3; 57/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=20
# [CV 2/3; 56/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=10;, score=0.569 total time=   0.3s
# [CV 2/3; 57/2160] START criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=20
# [CV 2/3; 54/2160] END criterion=entropy, max_depth=3, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.633 total time=   1.5s
# ...
# [CV 2/3; 2146/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/3; 2146/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=10
# [CV 3/3; 2146/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/3; 2147/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=20
# [CV 1/3; 2147/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 2/3; 2147/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=20
# [CV 2/3; 2147/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 3/3; 2147/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=20
# [CV 3/3; 2147/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=20;, score=nan total time=   0.0s
# [CV 1/3; 2148/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=30
# [CV 1/3; 2148/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 2/3; 2148/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=30
# [CV 2/3; 2148/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 3/3; 2148/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=30
# [CV 3/3; 2148/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=30;, score=nan total time=   0.0s
# [CV 1/3; 2149/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=40
# [CV 1/3; 2149/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 2/3; 2149/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=40
# [CV 2/3; 2149/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 3/3; 2149/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=40
# [CV 3/3; 2149/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=40;, score=nan total time=   0.0s
# [CV 1/3; 2150/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=50
# [CV 1/3; 2150/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/3; 2150/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=50
# [CV 2/3; 2150/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/3; 2150/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=50
# [CV 3/3; 2150/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=1, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/3; 2151/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=10
# [CV 1/3; 2151/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=10;, score=0.822 total time=   0.3s
# [CV 2/3; 2151/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=10
# [CV 3/3; 2143/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=3, n_estimators=30;, score=0.863 total time=   1.4s
# [CV 3/3; 2151/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=10
# [CV 2/3; 2151/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=10;, score=0.833 total time=   0.3s
# [CV 1/3; 2152/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=20
# [CV 3/3; 2151/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=10;, score=0.833 total time=   0.4s
# [CV 2/3; 2152/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=20
# [CV 1/3; 2144/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=0.868 total time=   1.9s
# [CV 3/3; 2152/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=20
# [CV 3/3; 2144/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=0.863 total time=   1.8s
# [CV 1/3; 2153/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=30
# [CV 2/3; 2144/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=0.882 total time=   2.1s
# [CV 2/3; 2153/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=30
# [CV 1/3; 2152/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=20;, score=0.837 total time=   0.9s
# [CV 3/3; 2153/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=30
# [CV 1/3; 2145/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.864 total time=   2.4s
# [CV 1/3; 2154/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=40
# [CV 2/3; 2145/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.883 total time=   2.5s
# [CV 2/3; 2154/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=40
# [CV 2/3; 2152/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=20;, score=0.849 total time=   1.0s
# [CV 3/3; 2154/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=40
# [CV 3/3; 2152/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=20;, score=0.840 total time=   1.2s
# [CV 1/3; 2155/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=50
# [CV 3/3; 2145/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.871 total time=   2.5s
# [CV 2/3; 2155/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=50
# [CV 1/3; 2153/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=30;, score=0.827 total time=   1.5s
# [CV 3/3; 2155/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=50
# [CV 2/3; 2153/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=30;, score=0.859 total time=   1.5s
# [CV 1/3; 2156/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=10
# [CV 1/3; 2156/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=10;, score=0.821 total time=   0.3s
# [CV 2/3; 2156/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=10
# [CV 3/3; 2153/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=30;, score=0.842 total time=   1.4s
# [CV 3/3; 2156/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=10
# [CV 2/3; 2156/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=10;, score=0.831 total time=   0.4s
# [CV 1/3; 2157/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=20
# [CV 3/3; 2156/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=10;, score=0.841 total time=   0.4s
# [CV 2/3; 2157/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=20
# [CV 1/3; 2154/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.828 total time=   1.8s
# [CV 3/3; 2157/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=20
# [CV 2/3; 2154/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.859 total time=   1.9s
# [CV 1/3; 2158/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=30
# [CV 3/3; 2154/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.840 total time=   1.9s
# [CV 2/3; 2158/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=30
# [CV 2/3; 2155/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=50;, score=0.849 total time=   2.3s
# [CV 3/3; 2158/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=30
# [CV 1/3; 2155/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=50;, score=0.842 total time=   2.5s
# [CV 1/3; 2159/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=40
# [CV 1/3; 2157/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=20;, score=0.835 total time=   1.3s
# [CV 2/3; 2159/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=40
# [CV 3/3; 2157/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=20;, score=0.830 total time=   1.2s
# [CV 3/3; 2159/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=40
# [CV 2/3; 2157/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=20;, score=0.853 total time=   1.4s
# [CV 1/3; 2160/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=50
# [CV 3/3; 2155/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=2, n_estimators=50;, score=0.842 total time=   2.7s
# [CV 2/3; 2160/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=50
# [CV 1/3; 2158/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=30;, score=0.838 total time=   1.9s
# [CV 3/3; 2160/2160] START criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=50
# [CV 2/3; 2158/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=30;, score=0.848 total time=   1.9s
# [CV 3/3; 2158/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=30;, score=0.839 total time=   1.7s
# [CV 1/3; 2159/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.838 total time=   2.2s
# [CV 2/3; 2159/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.854 total time=   2.1s
# [CV 3/3; 2159/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.850 total time=   2.1s
# [CV 1/3; 2160/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=50;, score=0.830 total time=   2.3s
# [CV 2/3; 2160/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=50;, score=0.850 total time=   2.1s
# [CV 3/3; 2160/2160] END criterion=log_loss, max_depth=None, max_features=7, min_samples_leaf=3, min_samples_split=3, n_estimators=50;, score=0.844 total time=   1.8s
# C:\Users\jkaszyda\.conda\envs\DeepLearning\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 2160 fits failed out of a total of 6480.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jkaszyda\.conda\envs\DeepLearning\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jkaszyda\.conda\envs\DeepLearning\lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\jkaszyda\.conda\envs\DeepLearning\lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\jkaszyda\.conda\envs\DeepLearning\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\jkaszyda\.conda\envs\DeepLearning\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan ... 0.84190207 0.84745763 0.84124294]
#   warnings.warn(

# %%
print('Best hyperparameters are: '+str(model_grid.best_params_))
print('Best score is: '+str(model_grid.best_score_))
# Out:
# Best hyperparameters are: {'criterion': 'entropy', 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 50}
# Best score is: 0.9160075329566855

# %%
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y_pred = model.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            7       0.91      0.93      0.92       451
#           15       0.94      0.96      0.95       427
#           16       0.98      1.00      0.99       454
#           21       0.95      1.00      0.98       446
#           33       0.92      0.86      0.89       453
#           34       1.00      1.00      1.00       420
#           39       1.00      1.00      1.00       433
#           56       0.88      0.91      0.89       444
#           68       0.81      0.84      0.82       438
#           95       0.97      1.00      0.98       409
#         1000       0.92      0.81      0.86       408
#         1001       0.88      0.84      0.86       449
#
#     accuracy                           0.93      5232
#    macro avg       0.93      0.93      0.93      5232
# weighted avg       0.93      0.93      0.93      5232

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
disp.plot()
plt.show()
